# %%
from datetime import datetime

wrong_proportion_seq = [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3]

for wrong_proportion in wrong_proportion_seq:
    print(wrong_proportion)
    # %run Fig2_main_prop.ipynb
    print(datetime.now())
# Out:
# 0
# /home/shpaik/21-aaai2022v2/Fig2/Sensitivity_prop
# Python 3.6.10 :: Anaconda, Inc.
# /home/shpaik/anaconda3/envs/py36/bin/python
# /home/shpaik/21-aaai2022v2/Fig2/Sensitivity_prop
# --------------------
# to1_1: 40, to1_2: 0.0004,
# <set models>
# SCLUB, time = 0.0005793571472167969 sec
# DyClu, time = 0.0001125335693359375 sec
# ...
# (v= 0.001 lam= 0.01 ) 0 user: 1 / selected arms: -1 -1 -1 5 -1 -1 5 -1 -1 -1 -1 -1 / opt_arm: 2 / time : 0.001 sec
# =====
# (v= 0.001 lam= 0.01 ) 250 user: 20 / selected arms: -1 -1 -1 5 -1 -1 4 -1 -1 -1 -1 -1 / opt_arm: 9 / time : 0.01 sec
# =====
# (v= 0.001 lam= 0.01 ) 500 user: 11 / selected arms: -1 -1 -1 7 -1 -1 7 -1 -1 -1 -1 -1 / opt_arm: 7 / time : 0.013 sec
# =====
# (v= 0.001 lam= 0.01 ) 750 user: 12 / selected arms: -1 -1 -1 5 -1 -1 3 -1 -1 -1 -1 -1 / opt_arm: 2 / time : 0.014 sec
# =====
# (v= 0.001 lam= 0.01 ) 1000 user: 22 / selected arms: -1 -1 -1 3 -1 -1 6 -1 -1 -1 -1 -1 / opt_arm: 4 / time : 0.014 sec
# =====
# ...
